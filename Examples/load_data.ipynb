# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
path = '/Users/gsw/Downloads'
file_list = sorted(glob.glob(os.path.join(path,'canais*.csv')))
pd.Series(file_list)
# Out:
# 0    /Users/gsw/Downloads/canais_2020-08-18_16-29-3...
# 1    /Users/gsw/Downloads/canais_2020-08-18_17-49-3...
# 2    /Users/gsw/Downloads/canais_2020-08-18_17-51-2...
# 3    /Users/gsw/Downloads/canais_2020-08-18_17-52-0...
# 4    /Users/gsw/Downloads/canais_2020-08-18_17-52-1...
# dtype: object

# %%
data = pd.read_csv(file_list[-1])
fig,ax = plt.subplots(1,1,figsize=(8,6))
#--
ax0=ax
ax0.plot(data['time(s)'],data['voltage_0'])
ax0.plot(data['time(s)'],data['voltage_2'])
ax0.set_xlabel('Tempo (s)')
ax0.set_ylabel('Tensão (arb.)')
# Out:
# Text(0, 0.5, 'Tensão (arb.)')

# %%
fig,ax = plt.subplots(1,1,figsize=(8,6))
#--
ax0=ax
ax0.plot(data['time(s)'],data['voltage_0'])
ax0.plot(data['time(s)'],data['voltage_2'])
ax0.set_xlabel('Tempo (s)')
ax0.set_ylabel('Tensão (arb.)')
# Out:
# Text(0, 0.5, 'Tensão (arb.)')
